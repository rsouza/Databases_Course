# %% [markdown]
# ## Introduction to Databases
#
# ### [Python ODO](http://odo.pydata.org/en/latest/)
#
#
# ![ODO image](http://odo.pydata.org/en/latest/_images/conversions.png)

# %%
# !pip install -q git+git://github.com/blaze/odo

# %%
import pandas as pd
from odo import odo

# %% [markdown]
# #### load source into target
#     odo(source, target)
#
#
# + odo(df, list)  # create new list from Pandas DataFrame
# + odo(df, [])  # append onto existing list
# + odo(df, 'myfile.json')  # Dump dataframe to line-delimited JSON
# + odo('myfiles.*.csv', Iterator) # Stream through many CSV files
# + odo(df, 'postgresql://hostname::tablename')  # Migrate dataframe to Postgres
# + odo('myfile.*.csv', 'postgresql://hostname::tablename')  # Load CSVs to Postgres
# + odo('postgresql://hostname::tablename', 'myfile.json') # Dump Postgres to JSON
# + odo('mongodb://hostname/db::collection', pd.DataFrame) # Dump Mongo to DataFrame
#
# Pay attention to [Data Shapes](https://odo.readthedocs.io/en/latest/datashape.html)

# %%
df_fake = odo("../SampleDBs/fakedata.csv", pd.DataFrame, sep='|')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ba634aa84572> in <module>
# ----> 1 df_fake = odo("../SampleDBs/fakedata.csv", pd.DataFrame, sep='|')
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/odo.py in odo(source, target, **kwargs)
#      89     odo.append.append      - Add things onto existing things
#      90     """
# ---> 91     return into(target, source, **kwargs)
#
# ~/environments/default_env/lib/python3.8/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     276             self._cache[types] = func
#     277         try:
# --> 278             return func(*args, **kwargs)
#     279
#     280         except MDNotImplementedError:
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/into.py in wrapped(*args, **kwargs)
#      41             raise TypeError('dshape argument is not an instance of DataShape')
#      42         kwargs['dshape'] = dshape
# ---> 43         return f(*args, **kwargs)
#      44     return wrapped
#      45
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/into.py in into_string_string(a, b, **kwargs)
#     147 @validate
#     148 def into_string_string(a, b, **kwargs):
# --> 149     return into(a, resource(b, **kwargs), **kwargs)
#     150
#     151
#
# ~/environments/default_env/lib/python3.8/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     276             self._cache[types] = func
#     277         try:
# --> 278             return func(*args, **kwargs)
#     279
#     280         except MDNotImplementedError:
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/into.py in wrapped(*args, **kwargs)
#      41             raise TypeError('dshape argument is not an instance of DataShape')
#      42         kwargs['dshape'] = dshape
# ---> 43         return f(*args, **kwargs)
#      44     return wrapped
#      45
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/into.py in into_type(a, b, dshape, **kwargs)
#      50     with ignoring(NotImplementedError):
#      51         if dshape is None:
# ---> 52             dshape = discover(b)
#      53     return convert(a, b, dshape=dshape, **kwargs)
#      54
#
# ~/environments/default_env/lib/python3.8/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     276             self._cache[types] = func
#     277         try:
# --> 278             return func(*args, **kwargs)
#     279
#     280         except MDNotImplementedError:
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/backends/csv.py in discover_csv(c, nrows, **kwargs)
#     375 @discover.register(CSV)
#     376 def discover_csv(c, nrows=1000, **kwargs):
# --> 377     df = csv_to_dataframe(c, nrows=nrows, **kwargs)
#     378     df = coerce_datetimes(df)
#     379
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/backends/csv.py in csv_to_dataframe(c, dshape, chunksize, nrows, **kwargs)
#     293 def csv_to_dataframe(c, dshape=None, chunksize=None, nrows=None, **kwargs):
#     294     try:
# --> 295         return _csv_to_dataframe(c, dshape=dshape, chunksize=chunksize,
#     296                                  nrows=nrows, **kwargs)
#     297     except StopIteration:
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/backends/csv.py in _csv_to_dataframe(c, dshape, chunksize, **kwargs)
#     344             header = None
#     345
# --> 346     kwargs = keyfilter(keywords(pd.read_csv).__contains__, kwargs)
#     347     with c.open() as f:
#     348         return pd.read_csv(f,
#
# ~/environments/default_env/lib/python3.8/site-packages/odo/utils.py in keywords(func)
#     128     if isinstance(func, type):
#     129         return keywords(func.__init__)
# --> 130     return inspect.getargspec(func).args
#     131
#     132
#
# /usr/lib/python3.8/inspect.py in getargspec(func)
#    1081         getfullargspec(func)
#    1082     if kwonlyargs or ann:
# -> 1083         raise ValueError("Function has keyword-only parameters or annotations"
#    1084                          ", use inspect.signature() API which can support them")
#    1085     return ArgSpec(args, varargs, varkw, defaults)
#
# ValueError: Function has keyword-only parameters or annotations, use inspect.signature() API which can support them
